# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as p
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={weather_api_key}"
#url = f"http://api.openweathermap.org/geo/1.0/direct?appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    #if (i > 5): break

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f"&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #p.pprint(city_weather) # debug

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['city']['coord']['lat']
        #print(city_lat)
        city_lng = city_weather['city']['coord']['lon']
        #print(city_lng)
        city_max_temp = city_weather['list'][0]['main']['temp_max']
        #print(city_max_temp)
        city_humidity = city_weather['list'][0]['main']['humidity']
        #print(city_humidity)
        city_clouds = city_weather['list'][0]['clouds']['all']
        #print(city_clouds)
        city_wind = city_weather['list'][0]['wind']['speed']
        #print(city_wind)
        city_country = city_weather['city']['country']
        #print(city_country)
        city_date = city_weather['list'][0]['dt_txt']
        #print(city_date)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

        #p.pprint(city_data)

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | harstad
# Processing Record 3 of Set 1 | vorgashor
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | labytnangi
# Processing Record 6 of Set 1 | baglung
# Processing Record 7 of Set 1 | sanya
# Processing Record 8 of Set 1 | bitam
# Processing Record 9 of Set 1 | gizo
# Processing Record 10 of Set 1 | colonia
# Processing Record 11 of Set 1 | klyuchi
# Processing Record 12 of Set 1 | golitsyno
# Processing Record 13 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 1 | torit
# Processing Record 15 of Set 1 | fruita
# Processing Record 16 of Set 1 | pibor
# City not found. Skipping...
# Processing Record 17 of Set 1 | turpan
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | weno
# Processing Record 20 of Set 1 | guerrero negro
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | grytviken
# Processing Record 24 of Set 1 | coracora
# Processing Record 25 of Set 1 | saint-pierre
# Processing Record 26 of Set 1 | puerto natales
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | harur
# Processing Record 29 of Set 1 | ciudad lazaro cardenas
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | alpena
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | invercargill
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | bireun
# Processing Record 39 of Set 1 | keflavik
# Processing Record 40 of Set 1 | lihue
# Processing Record 41 of Set 1 | waitangi
# Processing Record 42 of Set 1 | badger
# Processing Record 43 of Set 1 | santa rita
# Processing Record 44 of Set 1 | oamaru
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | margaret river
# Processing Record 47 of Set 1 | polyarnyy
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | crane
# Processing Record 50 of Set 1 | nova sintra
# Processing Record 0 of Set 2 | west bay
# Processing Record 1 of Set 2 | kiunga
# Processing Record 2 of Set 2 | zouerate
# Processing Record 3 of Set 2 | troitsk
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | imbituba
# Processing Record 7 of Set 2 | manokwari
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | pimentel
# Processing Record 10 of Set 2 | puerto aysen
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | wailua homesteads
# Processing Record 13 of Set 2 | verdal
# Processing Record 14 of Set 2 | saipan
# Processing Record 15 of Set 2 | saskatoon
# Processing Record 16 of Set 2 | novyy urgal
# Processing Record 17 of Set 2 | thanh hoa
# Processing Record 18 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 19 of Set 2 | igrim
# Processing Record 20 of Set 2 | kununurra
# Processing Record 21 of Set 2 | sur
# Processing Record 22 of Set 2 | kutum
# Processing Record 23 of Set 2 | hawaiian paradise park
# Processing Record 24 of Set 2 | bamboo flat
# Processing Record 25 of Set 2 | jucas
# Processing Record 26 of Set 2 | udachny
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | ola
# Processing Record 29 of Set 2 | st. john's
# Processing Record 30 of Set 2 | sosnovo-ozerskoye
# Processing Record 31 of Set 2 | lushoto
# Processing Record 32 of Set 2 | dhalie
# Processing Record 33 of Set 2 | meizhou
# Processing Record 34 of Set 2 | lerwick
# Processing Record 35 of Set 2 | santa rosalia
# Processing Record 36 of Set 2 | ulanhot
# Processing Record 37 of Set 2 | blackmans bay
# Processing Record 38 of Set 2 | belyy yar
# Processing Record 39 of Set 2 | kapa'a
# Processing Record 40 of Set 2 | sisimiut
# Processing Record 41 of Set 2 | altoona
# Processing Record 42 of Set 2 | susuman
# Processing Record 43 of Set 2 | qarazhal
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | college
# Processing Record 46 of Set 2 | kuanda
# Processing Record 47 of Set 2 | cooma
# Processing Record 48 of Set 2 | kete krachi
# Processing Record 49 of Set 2 | murzuq
# Processing Record 0 of Set 3 | jackson
# Processing Record 1 of Set 3 | bubaque
# Processing Record 2 of Set 3 | mala
# Processing Record 3 of Set 3 | sinabang
# Processing Record 4 of Set 3 | loukhi
# Processing Record 5 of Set 3 | kalengwa
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | stanley
# Processing Record 8 of Set 3 | ushuaia
# Processing Record 9 of Set 3 | castillos
# Processing Record 10 of Set 3 | greenville
# Processing Record 11 of Set 3 | aq qayeh
# City not found. Skipping...
# Processing Record 12 of Set 3 | dudinka
# Processing Record 13 of Set 3 | puerto baquerizo moreno
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | thinadhoo
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | caribou
# Processing Record 18 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 19 of Set 3 | ouellah
# City not found. Skipping...
# Processing Record 20 of Set 3 | kangding
# Processing Record 21 of Set 3 | kingston
# Processing Record 22 of Set 3 | afaahiti
# Processing Record 23 of Set 3 | mogocha
# Processing Record 24 of Set 3 | uturoa
# Processing Record 25 of Set 3 | anadyr
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | la passe
# Processing Record 28 of Set 3 | floro
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | parras de la fuente
# Processing Record 31 of Set 3 | metahara
# Processing Record 32 of Set 3 | pratapgarh
# Processing Record 33 of Set 3 | beira
# Processing Record 34 of Set 3 | guaruja
# Processing Record 35 of Set 3 | bulnes
# Processing Record 36 of Set 3 | betio village
# Processing Record 37 of Set 3 | arkhangel'sk
# Processing Record 38 of Set 3 | ormara
# Processing Record 39 of Set 3 | hadibu
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 3 | daru
# Processing Record 44 of Set 3 | dauphin
# Processing Record 45 of Set 3 | shibirghan
# Processing Record 46 of Set 3 | chernyshevskiy
# Processing Record 47 of Set 3 | alo
# Processing Record 48 of Set 3 | papatowai
# Processing Record 49 of Set 3 | west island
# Processing Record 0 of Set 4 | little falls
# Processing Record 1 of Set 4 | olonkinbyen
# Processing Record 2 of Set 4 | whitehorse
# Processing Record 3 of Set 4 | kamina
# Processing Record 4 of Set 4 | tura
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | ulladulla
# Processing Record 8 of Set 4 | san carlos de bariloche
# Processing Record 9 of Set 4 | flying fish cove
# Processing Record 10 of Set 4 | qaqortoq
# Processing Record 11 of Set 4 | neiafu
# Processing Record 12 of Set 4 | mil'kovo
# Processing Record 13 of Set 4 | solnechnyy
# Processing Record 14 of Set 4 | dalnegorsk
# Processing Record 15 of Set 4 | rifle
# Processing Record 16 of Set 4 | bargara
# City not found. Skipping...
# Processing Record 17 of Set 4 | puerto ayacucho
# Processing Record 18 of Set 4 | es castell
# Processing Record 19 of Set 4 | yuzhno-kurilsk
# Processing Record 20 of Set 4 | kuraymah
# Processing Record 21 of Set 4 | choibalsan
# Processing Record 22 of Set 4 | kupang
# Processing Record 23 of Set 4 | uzgen
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | kawambwa
# Processing Record 26 of Set 4 | thunder bay
# Processing Record 27 of Set 4 | tsiombe
# Processing Record 28 of Set 4 | laminusa
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 31 of Set 4 | rio grande
# Processing Record 32 of Set 4 | saijo
# Processing Record 33 of Set 4 | fada
# Processing Record 34 of Set 4 | port mathurin
# Processing Record 35 of Set 4 | kenai
# Processing Record 36 of Set 4 | quellon
# Processing Record 37 of Set 4 | neryungri
# Processing Record 38 of Set 4 | puerto colombia
# Processing Record 39 of Set 4 | vilyuchinsk
# Processing Record 40 of Set 4 | portland
# Processing Record 41 of Set 4 | darwin
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | hammerfest
# Processing Record 44 of Set 4 | iskateley
# Processing Record 45 of Set 4 | jayapura
# Processing Record 46 of Set 4 | inirida
# Processing Record 47 of Set 4 | khandyga
# Processing Record 48 of Set 4 | north side
# Processing Record 49 of Set 4 | borogontsy
# Processing Record 0 of Set 5 | port douglas
# Processing Record 1 of Set 5 | bokoro
# Processing Record 2 of Set 5 | huntsville
# Processing Record 3 of Set 5 | ayr
# Processing Record 4 of Set 5 | alaghsas
# Processing Record 5 of Set 5 | constantia
# Processing Record 6 of Set 5 | ilhabela
# Processing Record 7 of Set 5 | xining
# Processing Record 8 of Set 5 | quebrangulo
# Processing Record 9 of Set 5 | sirte
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | punta arenas
# Processing Record 12 of Set 5 | guasdualito
# Processing Record 13 of Set 5 | sao vicente
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 16 of Set 5 | guankou
# Processing Record 17 of Set 5 | miyanoura
# City not found. Skipping...
# Processing Record 18 of Set 5 | brisas de zicatela
# Processing Record 19 of Set 5 | jamestown
# Processing Record 20 of Set 5 | belmonte
# Processing Record 21 of Set 5 | tokar
# Processing Record 22 of Set 5 | jau
# Processing Record 23 of Set 5 | makarska
# Processing Record 24 of Set 5 | el matama
# Processing Record 25 of Set 5 | vila franca do campo
# Processing Record 26 of Set 5 | rostovka
# Processing Record 27 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 28 of Set 5 | nyurba
# Processing Record 29 of Set 5 | kristiansund
# Processing Record 30 of Set 5 | kulhudhuffushi
# Processing Record 31 of Set 5 | tralee
# Processing Record 32 of Set 5 | chiredzi
# Processing Record 33 of Set 5 | ciudad sabinas hidalgo
# Processing Record 34 of Set 5 | arar
# Processing Record 35 of Set 5 | hamilton
# Processing Record 36 of Set 5 | taltal
# Processing Record 37 of Set 5 | zapala
# Processing Record 38 of Set 5 | san antonio de pale
# Processing Record 39 of Set 5 | ingeniero guillermo n. juarez
# Processing Record 40 of Set 5 | queenstown
# Processing Record 41 of Set 5 | sabang
# Processing Record 42 of Set 5 | palikir - national government center
# Processing Record 43 of Set 5 | tazovsky
# Processing Record 44 of Set 5 | el trebol
# Processing Record 45 of Set 5 | monticello
# Processing Record 46 of Set 5 | cuyo
# Processing Record 47 of Set 5 | kailua-kona
# Processing Record 48 of Set 5 | kapuskasing
# Processing Record 49 of Set 5 | dawesville
# Processing Record 0 of Set 6 | suva
# Processing Record 1 of Set 6 | tateyama
# Processing Record 2 of Set 6 | cova figueira
# Processing Record 3 of Set 6 | punto fijo
# Processing Record 4 of Set 6 | carbonear
# Processing Record 5 of Set 6 | santa cruz
# Processing Record 6 of Set 6 | kuhdasht
# Processing Record 7 of Set 6 | luanda
# Processing Record 8 of Set 6 | palmer
# Processing Record 9 of Set 6 | pedro ii
# Processing Record 10 of Set 6 | hassi messaoud
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | fisterra
# Processing Record 13 of Set 6 | sahaswan
# Processing Record 14 of Set 6 | sweetwater
# Processing Record 15 of Set 6 | mumbwa
# Processing Record 16 of Set 6 | carnarvon
# Processing Record 17 of Set 6 | shumikha
# Processing Record 18 of Set 6 | zaragoza
# Processing Record 19 of Set 6 | gasa
# Processing Record 20 of Set 6 | leh
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | luuq
# Processing Record 23 of Set 6 | vadso
# Processing Record 24 of Set 6 | praia da vitoria
# Processing Record 25 of Set 6 | holualoa
# Processing Record 26 of Set 6 | katsuren-haebaru
# Processing Record 27 of Set 6 | smirnykh
# Processing Record 28 of Set 6 | lebyazh'ye
# Processing Record 29 of Set 6 | senador guiomard
# Processing Record 30 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 31 of Set 6 | minacu
# City not found. Skipping...
# Processing Record 32 of Set 6 | kokkola
# Processing Record 33 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 34 of Set 6 | portage la prairie
# Processing Record 35 of Set 6 | sechura
# Processing Record 36 of Set 6 | ingeniero jacobacci
# Processing Record 37 of Set 6 | kudahuvadhoo
# Processing Record 38 of Set 6 | tayaman
# Processing Record 39 of Set 6 | port alfred
# Processing Record 40 of Set 6 | dzhalagash
# Processing Record 41 of Set 6 | baikonur
# Processing Record 42 of Set 6 | puerto francisco de orellana
# Processing Record 43 of Set 6 | bac lieu
# Processing Record 44 of Set 6 | malmesbury
# Processing Record 45 of Set 6 | san jose village
# City not found. Skipping...
# Processing Record 46 of Set 6 | pedro betancourt
# Processing Record 47 of Set 6 | gazojak
# Processing Record 48 of Set 6 | morehead city
# Processing Record 49 of Set 6 | happy valley-goose bay
# Processing Record 0 of Set 7 | talcahuano
# Processing Record 1 of Set 7 | rosetta
# Processing Record 2 of Set 7 | mitu
# Processing Record 3 of Set 7 | huesca
# Processing Record 4 of Set 7 | anloga
# Processing Record 5 of Set 7 | tapiramuta
# Processing Record 6 of Set 7 | as sulayyil
# Processing Record 7 of Set 7 | minbu
# Processing Record 8 of Set 7 | newman
# Processing Record 9 of Set 7 | peace river
# Processing Record 10 of Set 7 | saguenay
# Processing Record 11 of Set 7 | shiqian
# Processing Record 12 of Set 7 | fort bragg
# Processing Record 13 of Set 7 | andergrove
# Processing Record 14 of Set 7 | marka
# Processing Record 15 of Set 7 | utrik
# Processing Record 16 of Set 7 | diamantino
# Processing Record 17 of Set 7 | callao
# Processing Record 18 of Set 7 | hithadhoo
# Processing Record 19 of Set 7 | nova vicosa
# Processing Record 20 of Set 7 | sainte-anne-des-plaines
# Processing Record 21 of Set 7 | labuan
# Processing Record 22 of Set 7 | gadzhiyevo
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | brookings
# Processing Record 25 of Set 7 | angaur state
# Processing Record 26 of Set 7 | cuajinicuilapa
# Processing Record 27 of Set 7 | gizycko
# Processing Record 28 of Set 7 | taulaga
# Processing Record 29 of Set 7 | biltine
# Processing Record 30 of Set 7 | bima
# Processing Record 31 of Set 7 | el calafate
# Processing Record 32 of Set 7 | ozu
# Processing Record 33 of Set 7 | mount isa
# Processing Record 34 of Set 7 | smithers
# Processing Record 35 of Set 7 | pizarro
# Processing Record 36 of Set 7 | ashti
# Processing Record 37 of Set 7 | saint-francois
# Processing Record 38 of Set 7 | murun-kuren
# Processing Record 39 of Set 7 | nouadhibou
# Processing Record 40 of Set 7 | lubango
# Processing Record 41 of Set 7 | bonthe
# Processing Record 42 of Set 7 | tabou
# Processing Record 43 of Set 7 | timbuktu
# Processing Record 44 of Set 7 | porto novo
# Processing Record 45 of Set 7 | victoria
# Processing Record 46 of Set 7 | isafjordur
# Processing Record 47 of Set 7 | rayevskaya
# Processing Record 48 of Set 7 | valdez
# Processing Record 49 of Set 7 | shahr-e babak
# Processing Record 0 of Set 8 | antonio enes
# Processing Record 1 of Set 8 | kirakira
# Processing Record 2 of Set 8 | port glaud
# City not found. Skipping...
# Processing Record 3 of Set 8 | horta
# Processing Record 4 of Set 8 | bayanhongor
# Processing Record 5 of Set 8 | selkirk
# Processing Record 6 of Set 8 | al kharijah
# Processing Record 7 of Set 8 | lorengau
# Processing Record 8 of Set 8 | plastun
# Processing Record 9 of Set 8 | tomatlan
# Processing Record 10 of Set 8 | fort mcmurray
# Processing Record 11 of Set 8 | kuragino
# Processing Record 12 of Set 8 | aasiaat
# Processing Record 13 of Set 8 | prince rupert
# Processing Record 14 of Set 8 | ofunato
# Processing Record 15 of Set 8 | lompoc
# Processing Record 16 of Set 8 | zhanaozen
# Processing Record 17 of Set 8 | chibougamau
# Processing Record 18 of Set 8 | tofol
# Processing Record 19 of Set 8 | remire-montjoly
# Processing Record 20 of Set 8 | gournay-en-bray
# Processing Record 21 of Set 8 | karatuzskoye
# Processing Record 22 of Set 8 | tefe
# Processing Record 23 of Set 8 | tolanaro
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | naze
# Processing Record 26 of Set 8 | tabuk
# Processing Record 27 of Set 8 | nandu
# Processing Record 28 of Set 8 | minas de marcona
# Processing Record 29 of Set 8 | ust-nera
# Processing Record 30 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 8 | kuala belait
# Processing Record 32 of Set 8 | pisco
# Processing Record 33 of Set 8 | san mateo
# Processing Record 34 of Set 8 | canguaretama
# Processing Record 35 of Set 8 | aglona
# Processing Record 36 of Set 8 | monrovia
# Processing Record 37 of Set 8 | nuuk
# Processing Record 38 of Set 8 | iquique
# Processing Record 39 of Set 8 | dolbeau-mistassini
# Processing Record 40 of Set 8 | tottori
# Processing Record 41 of Set 8 | yeppoon
# Processing Record 42 of Set 8 | la'ie
# Processing Record 43 of Set 8 | suntar
# Processing Record 44 of Set 8 | murghob
# Processing Record 45 of Set 8 | punta del este
# Processing Record 46 of Set 8 | kongolo
# Processing Record 47 of Set 8 | masterton
# Processing Record 48 of Set 8 | quelimane
# Processing Record 49 of Set 8 | sao felix do xingu
# Processing Record 0 of Set 9 | korsakov
# Processing Record 1 of Set 9 | copiapo
# Processing Record 2 of Set 9 | balqash
# Processing Record 3 of Set 9 | akureyri
# Processing Record 4 of Set 9 | magistral'nyy
# Processing Record 5 of Set 9 | allende
# Processing Record 6 of Set 9 | telica
# Processing Record 7 of Set 9 | kainantu
# Processing Record 8 of Set 9 | kupino
# Processing Record 9 of Set 9 | al 'alamayn
# City not found. Skipping...
# Processing Record 10 of Set 9 | oyama
# Processing Record 11 of Set 9 | tazacorte
# Processing Record 12 of Set 9 | ban phe
# City not found. Skipping...
# Processing Record 13 of Set 9 | haiku-pauwela
# Processing Record 14 of Set 9 | santiago de cao
# Processing Record 15 of Set 9 | campbell river
# Processing Record 16 of Set 9 | burang
# Processing Record 17 of Set 9 | atafu village
# Processing Record 18 of Set 9 | aykhal
# Processing Record 19 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 20 of Set 9 | birao
# Processing Record 21 of Set 9 | maceio
# Processing Record 22 of Set 9 | port moresby
# Processing Record 23 of Set 9 | eau claire
# Processing Record 24 of Set 9 | akjoujt
# Processing Record 25 of Set 9 | clinton
# Processing Record 26 of Set 9 | rongelap
# Processing Record 27 of Set 9 | streator
# Processing Record 28 of Set 9 | sandnessjoen
# Processing Record 29 of Set 9 | leiyang
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | yanam
# Processing Record 32 of Set 9 | calvinia
# Processing Record 33 of Set 9 | bulanash
# Processing Record 34 of Set 9 | ballina
# Processing Record 35 of Set 9 | idukki
# Processing Record 36 of Set 9 | hua hin
# Processing Record 37 of Set 9 | waingapu
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | qa'en
# Processing Record 40 of Set 9 | petawawa
# Processing Record 41 of Set 9 | zyryanovsk
# Processing Record 42 of Set 9 | sayansk
# Processing Record 43 of Set 9 | bikenibeu village
# Processing Record 44 of Set 9 | zhalantun
# Processing Record 45 of Set 9 | rikaze
# Processing Record 46 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 47 of Set 9 | pau brasil
# Processing Record 48 of Set 9 | pudozh
# Processing Record 49 of Set 9 | glace bay
# Processing Record 0 of Set 10 | houlton
# Processing Record 1 of Set 10 | lodja
# Processing Record 2 of Set 10 | juan l. lacaze
# Processing Record 3 of Set 10 | ust'-ilimsk
# Processing Record 4 of Set 10 | piacabucu
# Processing Record 5 of Set 10 | kovalam
# Processing Record 6 of Set 10 | ankpa
# Processing Record 7 of Set 10 | ukwa
# Processing Record 8 of Set 10 | prado
# Processing Record 9 of Set 10 | semporna
# Processing Record 10 of Set 10 | wellington
# Processing Record 11 of Set 10 | kavaratti
# Processing Record 12 of Set 10 | kaa-khem
# Processing Record 13 of Set 10 | bopolu
# Processing Record 14 of Set 10 | faya-largeau
# Processing Record 15 of Set 10 | fukuecho
# Processing Record 16 of Set 10 | acarau
# Processing Record 17 of Set 10 | cill airne
# Processing Record 18 of Set 10 | nampa
# Processing Record 19 of Set 10 | uige
# Processing Record 20 of Set 10 | gerash
# Processing Record 21 of Set 10 | puerto deseado
# Processing Record 22 of Set 10 | shahrud
# Processing Record 23 of Set 10 | enewetak
# Processing Record 24 of Set 10 | luderitz
# Processing Record 25 of Set 10 | villena
# Processing Record 26 of Set 10 | pemangkat
# Processing Record 27 of Set 10 | bukama
# Processing Record 28 of Set 10 | altamira
# Processing Record 29 of Set 10 | sibolga
# Processing Record 30 of Set 10 | aldama
# Processing Record 31 of Set 10 | lethem
# Processing Record 32 of Set 10 | el fasher
# Processing Record 33 of Set 10 | el bauga
# Processing Record 34 of Set 10 | dongola
# Processing Record 35 of Set 10 | dapchi
# Processing Record 36 of Set 10 | barranca
# Processing Record 37 of Set 10 | yuli
# Processing Record 38 of Set 10 | colonia menno
# Processing Record 39 of Set 10 | luz
# Processing Record 40 of Set 10 | garachico
# Processing Record 41 of Set 10 | chonchi
# Processing Record 42 of Set 10 | magnaga
# Processing Record 43 of Set 10 | konosha
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | diego de almagro
# Processing Record 46 of Set 10 | tuzha
# Processing Record 47 of Set 10 | hohhot
# Processing Record 48 of Set 10 | tshabong
# Processing Record 49 of Set 10 | wimpassing
# Processing Record 0 of Set 11 | ribeira brava
# Processing Record 1 of Set 11 | asau village
# City not found. Skipping...
# Processing Record 2 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 3 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 4 of Set 11 | novi sanzhary
# Processing Record 5 of Set 11 | farshut
# Processing Record 6 of Set 11 | khromtau
# Processing Record 7 of Set 11 | kutno
# Processing Record 8 of Set 11 | zinjibar
# Processing Record 9 of Set 11 | kill devil hills
# Processing Record 10 of Set 11 | kukawa
# Processing Record 11 of Set 11 | taoudenni
# Processing Record 12 of Set 11 | nemuro
# Processing Record 13 of Set 11 | korhogo
# Processing Record 14 of Set 11 | kibaya
# Processing Record 15 of Set 11 | garoowe
# Processing Record 16 of Set 11 | williamston
# Processing Record 17 of Set 11 | dubbo
# Processing Record 18 of Set 11 | kavieng
# Processing Record 19 of Set 11 | tandag
# Processing Record 20 of Set 11 | mar del plata
# Processing Record 21 of Set 11 | phan rang-thap cham
# Processing Record 22 of Set 11 | mejit
# Processing Record 23 of Set 11 | san pedro pochutla
# Processing Record 24 of Set 11 | fort st. john
# Processing Record 25 of Set 11 | magadan
# Processing Record 26 of Set 11 | hadim
# Processing Record 27 of Set 11 | east independence
# Processing Record 28 of Set 11 | mersa matruh
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | lagoa
# Processing Record 31 of Set 11 | mugia
# Processing Record 32 of Set 11 | novoanninskiy
# Processing Record 33 of Set 11 | kunri
# Processing Record 34 of Set 11 | laojunmiao
# Processing Record 35 of Set 11 | qui nhon
# Processing Record 36 of Set 11 | tidjikja
# Processing Record 37 of Set 11 | taksimo
# Processing Record 38 of Set 11 | velyka bahachka
# Processing Record 39 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | doka
# Processing Record 41 of Set 11 | dili
# Processing Record 42 of Set 11 | winnemucca
# Processing Record 43 of Set 11 | akcaabat
# Processing Record 44 of Set 11 | ta`u
# Processing Record 45 of Set 11 | vyazemskiy
# Processing Record 46 of Set 11 | kloulklubed
# Processing Record 47 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 48 of Set 11 | codrington
# Processing Record 49 of Set 11 | severo-yeniseyskiy
# Processing Record 0 of Set 12 | bengkulu
# Processing Record 1 of Set 12 | maintirano
# Processing Record 2 of Set 12 | tubmanburg
# Processing Record 3 of Set 12 | tamanrasset
# Processing Record 4 of Set 12 | muisne
# Processing Record 5 of Set 12 | motupe
# Processing Record 6 of Set 12 | barcelos
# Processing Record 7 of Set 12 | rayside-balfour
# City not found. Skipping...
# Processing Record 8 of Set 12 | port washington
# Processing Record 9 of Set 12 | cabedelo
# Processing Record 10 of Set 12 | walvis bay
# Processing Record 11 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 12 of Set 12 | bryne
# Processing Record 13 of Set 12 | guiuan
# Processing Record 14 of Set 12 | saint-philippe
# Processing Record 15 of Set 12 | sarh
# Processing Record 16 of Set 12 | san juan
# Processing Record 17 of Set 12 | howrah
# Processing Record 18 of Set 12 | kuqa
# Processing Record 19 of Set 12 | brunsbuttel
# Processing Record 20 of Set 12 | boa vista
# Processing Record 21 of Set 12 | lacin
# Processing Record 22 of Set 12 | berezovyy
# Processing Record 23 of Set 12 | noumea
# Processing Record 24 of Set 12 | mariental
# Processing Record 25 of Set 12 | jizzax
# Processing Record 26 of Set 12 | safi
# Processing Record 27 of Set 12 | dryden
# Processing Record 28 of Set 12 | la punta
# Processing Record 29 of Set 12 | saudarkrokur
# Processing Record 30 of Set 12 | coxen hole
# Processing Record 31 of Set 12 | polokwane
# Processing Record 32 of Set 12 | krutinka
# Processing Record 33 of Set 12 | hasaki
# Processing Record 34 of Set 12 | ust-tsilma
# Processing Record 35 of Set 12 | galle
# Processing Record 36 of Set 12 | la ronge
# Processing Record 37 of Set 12 | sarov
# Processing Record 38 of Set 12 | camargo
# Processing Record 39 of Set 12 | behshahr
# Processing Record 40 of Set 12 | fortaleza
# Processing Record 41 of Set 12 | nadi
# Processing Record 42 of Set 12 | kalaleh
# Processing Record 43 of Set 12 | mana
# Processing Record 44 of Set 12 | morondava
# Processing Record 45 of Set 12 | ventnor
# Processing Record 46 of Set 12 | alvaro obregon
# Processing Record 47 of Set 12 | miquelon
# Processing Record 48 of Set 12 | usinsk
# Processing Record 49 of Set 12 | merizo village
# Processing Record 0 of Set 13 | reggane
# Processing Record 1 of Set 13 | arizona city
# Processing Record 2 of Set 13 | wainwright
# Processing Record 3 of Set 13 | mena
# Processing Record 4 of Set 13 | dano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df['Date'] = city_data_df['Date'].str.split(' ').str[0]
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   adamstown -25.0660 -130.1015    297.79        76          80        2.30
# 1     harstad  68.7990   16.5293    279.70       100         100        6.58
# 2   vorgashor  67.5833   63.9500    265.70        97         100        3.54
# 3     iqaluit  63.7506  -68.5145    268.55        92         100        7.51
# 4  labytnangi  66.6572   66.4183    264.07        91         100        2.14
#
#   Country        Date
# 0      PN  2023-04-19
# 1      NO  2023-04-19
# 2      RU  2023-04-19
# 3      CA  2023-04-19
# 4      RU  2023-04-19

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         adamstown -25.0660 -130.1015    297.79        76          80
# 1           harstad  68.7990   16.5293    279.70       100         100
# 2         vorgashor  67.5833   63.9500    265.70        97         100
# 3           iqaluit  63.7506  -68.5145    268.55        92         100
# 4        labytnangi  66.6572   66.4183    264.07        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.30      PN  2023-04-19
# 1              6.58      NO  2023-04-19
# 2              3.54      RU  2023-04-19
# 3              7.51      CA  2023-04-19
# 4              2.14      RU  2023-04-19

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Temperature ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Humidity ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Cloudiness ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Wind Speed ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_reg(x, y, title, x_label, y_label):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    regression_line = slope * x + intercept

    # Create scatter plot
    plt.scatter(x, y, marker='o', edgecolors='black', alpha=0.75)
    plt.plot(x, regression_line, color='red', linewidth=2, label=f'y = {slope:.2f}x + {intercept:.2f}\nR = {r_value:.2f}')
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           harstad  68.7990  16.5293    279.70       100         100
# 2         vorgashor  67.5833  63.9500    265.70        97         100
# 3           iqaluit  63.7506 -68.5145    268.55        92         100
# 4        labytnangi  66.6572  66.4183    264.07        91         100
# 5           baglung  28.2719  83.5898    293.34        33           2
#
#          Wind Speed Country        Date
# City_ID
# 1              6.58      NO  2023-04-19
# 2              3.54      RU  2023-04-19
# 3              7.51      CA  2023-04-19
# 4              2.14      RU  2023-04-19
# 5              3.21      NP  2023-04-19

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          adamstown -25.0660 -130.1015    297.79        76
# 8                               gizo  -8.1030  156.8419    300.55        65
# 18                              lebu -37.6167  -73.6500    287.31        83
# 19       edinburgh of the seven seas -37.0676  -12.3116    291.26        77
# 20                         grytviken -54.2811  -36.5092    276.41        96
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                80        2.30      PN  2023-04-19
# 8                17        1.57      SB  2023-04-19
# 18               90        8.50      CL  2023-04-19
# 19              100       10.38      SH  2023-04-19
# 20              100        1.82      GS  2023-04-19

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere: Temperature vs. Latitude
create_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'North Hemi: Max Temp vs. Lat', 'Latitude', 'Max Temp')

# %%
# Linear regression on Southern Hemisphere: Temperature vs. Latitude
create_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'South Hemi: Max Temp vs. Lat', 'Latitude', 'Max Temp')

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is a negative linear relationship between latitude and max temperature, with temperatures decreasing as latitude increases. In the southern hemisphere, there is a positive linear relationship, with temperatures increasing as latitude increases. The strength of the relationship is stronger in the northern hemisphere (R = -0.87) compared to the southern hemisphere (R = 0.73).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'North Hemi: Humidity vs. Lat', 'Latitude', 'Humidity')

# %%
# Southern Hemisphere
create_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'South Hemi: Humidity vs. Lat', 'Latitude', 'Humidity')

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak positive linear relationship between latitude and humidity in both the northern and southern hemispheres. The strength of the relationship is slightly stronger in the southern hemisphere (R = 0.21) compared to the northern hemisphere (R = 0.18).

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'North Hemi: Cloudiness vs. Lat', 'Latitude', 'Cloudiness')

# %%
# Southern Hemisphere
create_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'South Hemi: Cloudiness vs. Lat', 'Latitude', 'Cloudiness')

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak positive linear relationship between latitude and cloudiness in the northern hemisphere, with cloudiness slightly increasing as latitude increases. In the southern hemisphere, there is a weak negative linear relationship, with cloudiness slightly decreasing as latitude increases. The strength of the relationship is slightly stronger in the northern hemisphere (R = 0.20) compared to the southern hemisphere (R = -0.01).

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'North Hemi: Wind Speed vs. Lat', 'Latitude', 'Wind Speed')

# %%
# Southern Hemisphere
create_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'South Hemi: Wind Speed vs. Lat', 'Latitude', 'Wind Speed')

# %% [markdown]
# **Discussion about the linear relationship:** There is a very weak negative linear relationship between latitude and wind speed in both the northern and southern hemispheres, with wind speed decreasing slightly as latitude increases. The strength of the relationship is very weak in both hemispheres, with R-values close to zero (-0.01 in northern hemisphere and -0.29 in southern hemisphere).
