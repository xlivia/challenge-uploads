# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as p
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={weather_api_key}"
#url = f"http://api.openweathermap.org/geo/1.0/direct?appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    #if (i > 5): break

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f"&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #p.pprint(city_weather) # debug

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['city']['coord']['lat']
        #print(city_lat)
        city_lng = city_weather['city']['coord']['lon']
        #print(city_lng)
        city_max_temp = city_weather['list'][0]['main']['temp_max']
        #print(city_max_temp)
        city_humidity = city_weather['list'][0]['main']['humidity']
        #print(city_humidity)
        city_clouds = city_weather['list'][0]['clouds']['all']
        #print(city_clouds)
        city_wind = city_weather['list'][0]['wind']['speed']
        #print(city_wind)
        city_country = city_weather['city']['country']
        #print(city_country)
        city_date = city_weather['list'][0]['dt_txt']
        #print(city_date)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

        #p.pprint(city_data)

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabedelo
# Processing Record 2 of Set 1 | acarau
# Processing Record 3 of Set 1 | blairgowrie
# Processing Record 4 of Set 1 | sinmak
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | dryden
# Processing Record 7 of Set 1 | tsagan aman
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | tevriz
# Processing Record 10 of Set 1 | polyarnyy
# Processing Record 11 of Set 1 | sakakah
# Processing Record 12 of Set 1 | la ronge
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | gadzhiyevo
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | afaahiti
# Processing Record 17 of Set 1 | ola
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | nova sintra
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | madinat ash shamal
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | kill devil hills
# Processing Record 25 of Set 1 | st. john's
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | margaret river
# Processing Record 28 of Set 1 | bulungu
# Processing Record 29 of Set 1 | whangarei
# Processing Record 30 of Set 1 | bonthe
# Processing Record 31 of Set 1 | alekseyevka
# Processing Record 32 of Set 1 | fale old settlement
# Processing Record 33 of Set 1 | priozersk
# Processing Record 34 of Set 1 | byron bay
# Processing Record 35 of Set 1 | valga
# Processing Record 36 of Set 1 | hawaiian paradise park
# Processing Record 37 of Set 1 | udachny
# Processing Record 38 of Set 1 | nemuro
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | puerto natales
# Processing Record 41 of Set 1 | barcelos
# Processing Record 42 of Set 1 | qaqortoq
# Processing Record 43 of Set 1 | taoudenni
# Processing Record 44 of Set 1 | iskateley
# Processing Record 45 of Set 1 | lembar
# City not found. Skipping...
# Processing Record 46 of Set 1 | grytviken
# Processing Record 47 of Set 1 | enewetak
# Processing Record 48 of Set 1 | edinburgh of the seven seas
# Processing Record 49 of Set 1 | yelizovo
# Processing Record 50 of Set 1 | bilibino
# Processing Record 0 of Set 2 | batang
# Processing Record 1 of Set 2 | sitampiky
# City not found. Skipping...
# Processing Record 2 of Set 2 | tshikapa
# Processing Record 3 of Set 2 | ust-nera
# Processing Record 4 of Set 2 | anshun
# Processing Record 5 of Set 2 | blackmans bay
# Processing Record 6 of Set 2 | utrik
# Processing Record 7 of Set 2 | hamilton
# Processing Record 8 of Set 2 | nova vicosa
# Processing Record 9 of Set 2 | baluntaicun
# City not found. Skipping...
# Processing Record 10 of Set 2 | invercargill
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | isafjordur
# Processing Record 13 of Set 2 | onega
# Processing Record 14 of Set 2 | tofol
# Processing Record 15 of Set 2 | puerto armuelles
# Processing Record 16 of Set 2 | beausoleil
# Processing Record 17 of Set 2 | berdigestyakh
# Processing Record 18 of Set 2 | muynoq
# Processing Record 19 of Set 2 | bereznik
# Processing Record 20 of Set 2 | gobabis
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | poso
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | pacific grove
# Processing Record 28 of Set 2 | gizo
# Processing Record 29 of Set 2 | villanueva
# Processing Record 30 of Set 2 | ulsteinvik
# Processing Record 31 of Set 2 | visakhapatnam
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | newman
# Processing Record 34 of Set 2 | north bend
# Processing Record 35 of Set 2 | badger
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | dolores
# Processing Record 39 of Set 2 | thinadhoo
# Processing Record 40 of Set 2 | vanimo
# Processing Record 41 of Set 2 | kalmunai
# Processing Record 42 of Set 2 | wailua homesteads
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | kismayo
# Processing Record 45 of Set 2 | praia
# Processing Record 46 of Set 2 | ha'il
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | dzhangala
# Processing Record 49 of Set 2 | sa pa
# Processing Record 0 of Set 3 | stanley
# Processing Record 1 of Set 3 | mahdalynivka
# Processing Record 2 of Set 3 | bay roberts
# Processing Record 3 of Set 3 | vila franca do campo
# Processing Record 4 of Set 3 | pimentel
# Processing Record 5 of Set 3 | bac ninh
# Processing Record 6 of Set 3 | kitimat
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | lycksele
# Processing Record 9 of Set 3 | sarangani
# Processing Record 10 of Set 3 | kapuskasing
# Processing Record 11 of Set 3 | mejit
# Processing Record 12 of Set 3 | pacocha
# Processing Record 13 of Set 3 | mong cai
# City not found. Skipping...
# Processing Record 14 of Set 3 | puerto baquerizo moreno
# Processing Record 15 of Set 3 | jala
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | puerto lempira
# Processing Record 18 of Set 3 | guarapari
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 3 | namibe
# Processing Record 22 of Set 3 | constantia
# Processing Record 23 of Set 3 | tobelo
# Processing Record 24 of Set 3 | albany
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | inderbor
# Processing Record 29 of Set 3 | fort mcmurray
# Processing Record 30 of Set 3 | maamba
# Processing Record 31 of Set 3 | weno
# Processing Record 32 of Set 3 | hotan
# Processing Record 33 of Set 3 | port lincoln
# Processing Record 34 of Set 3 | papatowai
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | sao francisco
# Processing Record 38 of Set 3 | sao tome
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | praia da vitoria
# Processing Record 41 of Set 3 | hengchun
# Processing Record 42 of Set 3 | chibougamau
# Processing Record 43 of Set 3 | kayenta
# Processing Record 44 of Set 3 | greenville
# Processing Record 45 of Set 3 | corfu
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | tutong
# Processing Record 48 of Set 3 | solwezi
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 0 of Set 4 | kodiak
# Processing Record 1 of Set 4 | chonchi
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | bodo
# Processing Record 4 of Set 4 | farkhar
# Processing Record 5 of Set 4 | riyadh
# Processing Record 6 of Set 4 | tazovsky
# Processing Record 7 of Set 4 | northam
# Processing Record 8 of Set 4 | el charco
# Processing Record 9 of Set 4 | akureyri
# Processing Record 10 of Set 4 | saint-pierre
# Processing Record 11 of Set 4 | la'ie
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | margate
# Processing Record 14 of Set 4 | sibolga
# Processing Record 15 of Set 4 | khanty-mansiysk
# Processing Record 16 of Set 4 | yemva
# Processing Record 17 of Set 4 | quang ngai
# Processing Record 18 of Set 4 | glen innes
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | vilyuysk
# Processing Record 21 of Set 4 | al ghayzah
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | gamboula
# Processing Record 24 of Set 4 | sardinata
# Processing Record 25 of Set 4 | sumbe
# Processing Record 26 of Set 4 | haiku-pauwela
# Processing Record 27 of Set 4 | lihue
# Processing Record 28 of Set 4 | saipan
# Processing Record 29 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 30 of Set 4 | kincardine
# Processing Record 31 of Set 4 | inhambane
# Processing Record 32 of Set 4 | whitehorse
# Processing Record 33 of Set 4 | ziro
# Processing Record 34 of Set 4 | hermanus
# Processing Record 35 of Set 4 | lutes mountain
# City not found. Skipping...
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | chipinge
# Processing Record 38 of Set 4 | ocean pointe
# City not found. Skipping...
# Processing Record 39 of Set 4 | malkerns
# Processing Record 40 of Set 4 | orchard homes
# Processing Record 41 of Set 4 | dem'yanovo
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | inari
# Processing Record 44 of Set 4 | avarua
# Processing Record 45 of Set 4 | vorgashor
# Processing Record 46 of Set 4 | dera ghazi khan
# Processing Record 47 of Set 4 | luganville
# Processing Record 48 of Set 4 | ouesso
# Processing Record 49 of Set 4 | arteche
# Processing Record 0 of Set 5 | ivdel'
# Processing Record 1 of Set 5 | duba
# Processing Record 2 of Set 5 | vernon
# Processing Record 3 of Set 5 | kenora
# Processing Record 4 of Set 5 | phongsali
# Processing Record 5 of Set 5 | tobol'sk
# Processing Record 6 of Set 5 | olinda
# Processing Record 7 of Set 5 | galesong
# Processing Record 8 of Set 5 | pariang
# City not found. Skipping...
# Processing Record 9 of Set 5 | sadjoavato
# City not found. Skipping...
# Processing Record 10 of Set 5 | baardheere
# Processing Record 11 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 12 of Set 5 | bullhead city
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | khorugh
# Processing Record 15 of Set 5 | oltinko'l
# Processing Record 16 of Set 5 | callao
# Processing Record 17 of Set 5 | chake chake
# Processing Record 18 of Set 5 | sabzevar
# Processing Record 19 of Set 5 | jieshi
# Processing Record 20 of Set 5 | sidi ifni
# Processing Record 21 of Set 5 | taroa
# Processing Record 22 of Set 5 | chui
# Processing Record 23 of Set 5 | port mathurin
# Processing Record 24 of Set 5 | horta
# Processing Record 25 of Set 5 | keflavik
# Processing Record 26 of Set 5 | aksaray
# Processing Record 27 of Set 5 | carolina beach
# Processing Record 28 of Set 5 | tura
# Processing Record 29 of Set 5 | tambopata
# Processing Record 30 of Set 5 | embi
# Processing Record 31 of Set 5 | takamaka
# City not found. Skipping...
# Processing Record 32 of Set 5 | wenchang
# Processing Record 33 of Set 5 | padang
# Processing Record 34 of Set 5 | olonkinbyen
# Processing Record 35 of Set 5 | glace bay
# Processing Record 36 of Set 5 | najran
# Processing Record 37 of Set 5 | sharlyk
# Processing Record 38 of Set 5 | al 'alamayn
# City not found. Skipping...
# Processing Record 39 of Set 5 | kita
# Processing Record 40 of Set 5 | uruacu
# Processing Record 41 of Set 5 | ca mau
# Processing Record 42 of Set 5 | wotje
# Processing Record 43 of Set 5 | tazacorte
# Processing Record 44 of Set 5 | nyurba
# Processing Record 45 of Set 5 | pazaryolu
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | nabire
# Processing Record 48 of Set 5 | leer
# Processing Record 49 of Set 5 | oberviechtach
# Processing Record 0 of Set 6 | klyuchi
# Processing Record 1 of Set 6 | tabou
# Processing Record 2 of Set 6 | ciudad lazaro cardenas
# Processing Record 3 of Set 6 | tolanaro
# Processing Record 4 of Set 6 | juliaca
# Processing Record 5 of Set 6 | potiskum
# Processing Record 6 of Set 6 | ussel
# Processing Record 7 of Set 6 | kirensk
# Processing Record 8 of Set 6 | cannonvale
# Processing Record 9 of Set 6 | amga
# Processing Record 10 of Set 6 | remire-montjoly
# Processing Record 11 of Set 6 | nar'yan-mar
# Processing Record 12 of Set 6 | atar
# Processing Record 13 of Set 6 | janze
# Processing Record 14 of Set 6 | alofi
# Processing Record 15 of Set 6 | faya-largeau
# Processing Record 16 of Set 6 | sechura
# Processing Record 17 of Set 6 | an nuhud
# Processing Record 18 of Set 6 | sao joao da barra
# Processing Record 19 of Set 6 | kuytun
# Processing Record 20 of Set 6 | lospalos
# Processing Record 21 of Set 6 | lisala
# Processing Record 22 of Set 6 | n'zeto
# Processing Record 23 of Set 6 | hami
# Processing Record 24 of Set 6 | bensonville
# Processing Record 25 of Set 6 | magadan
# Processing Record 26 of Set 6 | itapecerica
# Processing Record 27 of Set 6 | west island
# Processing Record 28 of Set 6 | santa terezinha
# Processing Record 29 of Set 6 | kiunga
# Processing Record 30 of Set 6 | fuglafjordur
# Processing Record 31 of Set 6 | quellon
# Processing Record 32 of Set 6 | walvis bay
# Processing Record 33 of Set 6 | kalemie
# Processing Record 34 of Set 6 | santa rosa de cabal
# Processing Record 35 of Set 6 | lannemezan
# Processing Record 36 of Set 6 | tabuk
# Processing Record 37 of Set 6 | concordia
# Processing Record 38 of Set 6 | richards bay
# Processing Record 39 of Set 6 | dampit
# Processing Record 40 of Set 6 | aasiaat
# Processing Record 41 of Set 6 | pelhrimov
# Processing Record 42 of Set 6 | san felipe jalapa de diaz
# Processing Record 43 of Set 6 | manaure
# Processing Record 44 of Set 6 | port blair
# Processing Record 45 of Set 6 | snyder
# Processing Record 46 of Set 6 | djenne
# Processing Record 47 of Set 6 | san antonio de pale
# Processing Record 48 of Set 6 | laojunmiao
# Processing Record 49 of Set 6 | benjamin aceval
# Processing Record 0 of Set 7 | 'ibri
# City not found. Skipping...
# Processing Record 1 of Set 7 | goondiwindi
# Processing Record 2 of Set 7 | kingston
# Processing Record 3 of Set 7 | hoxtolgay
# City not found. Skipping...
# Processing Record 4 of Set 7 | roslavl'
# Processing Record 5 of Set 7 | timmins
# Processing Record 6 of Set 7 | anadyr
# Processing Record 7 of Set 7 | tralee
# Processing Record 8 of Set 7 | srikakulam
# Processing Record 9 of Set 7 | pangody
# Processing Record 10 of Set 7 | nizhniy ingash
# Processing Record 11 of Set 7 | ma'an
# Processing Record 12 of Set 7 | champerico
# Processing Record 13 of Set 7 | port alfred
# Processing Record 14 of Set 7 | taloda
# Processing Record 15 of Set 7 | uturoa
# Processing Record 16 of Set 7 | barah
# Processing Record 17 of Set 7 | manadhoo
# Processing Record 18 of Set 7 | kapa'a
# Processing Record 19 of Set 7 | sittwe
# Processing Record 20 of Set 7 | magdagachi
# Processing Record 21 of Set 7 | erenhot
# Processing Record 22 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 23 of Set 7 | felege neway
# Processing Record 24 of Set 7 | vadso
# Processing Record 25 of Set 7 | mutoko
# Processing Record 26 of Set 7 | cidreira
# Processing Record 27 of Set 7 | nyagan
# Processing Record 28 of Set 7 | cuatro cienegas de carranza
# Processing Record 29 of Set 7 | luga
# Processing Record 30 of Set 7 | san sebastian de la gomera
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | tadine
# Processing Record 33 of Set 7 | laguna
# Processing Record 34 of Set 7 | kargopol'
# Processing Record 35 of Set 7 | sukumo
# Processing Record 36 of Set 7 | mana
# Processing Record 37 of Set 7 | nizhneangarsk
# Processing Record 38 of Set 7 | calingasta
# Processing Record 39 of Set 7 | portland
# Processing Record 40 of Set 7 | pariaman
# Processing Record 41 of Set 7 | warman
# Processing Record 42 of Set 7 | wotho
# Processing Record 43 of Set 7 | usinsk
# Processing Record 44 of Set 7 | vilyuchinsk
# Processing Record 45 of Set 7 | ta`u
# Processing Record 46 of Set 7 | chaeryong-up
# Processing Record 47 of Set 7 | sisimiut
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | port said
# Processing Record 0 of Set 8 | tarawa
# Processing Record 1 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 8 | umm kaddadah
# Processing Record 3 of Set 8 | islampur
# Processing Record 4 of Set 8 | maloye ganyushkino
# Processing Record 5 of Set 8 | takoradi
# Processing Record 6 of Set 8 | bossier city
# Processing Record 7 of Set 8 | sona
# Processing Record 8 of Set 8 | dazhou
# Processing Record 9 of Set 8 | minas de marcona
# Processing Record 10 of Set 8 | mount isa
# Processing Record 11 of Set 8 | lubang
# Processing Record 12 of Set 8 | danville
# Processing Record 13 of Set 8 | labrador city
# Processing Record 14 of Set 8 | hammerfest
# Processing Record 15 of Set 8 | tangalle
# Processing Record 16 of Set 8 | ambalangoda
# Processing Record 17 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 8 | salinas
# Processing Record 19 of Set 8 | dudinka
# Processing Record 20 of Set 8 | saint-philippe
# Processing Record 21 of Set 8 | bafra
# Processing Record 22 of Set 8 | sioux falls
# Processing Record 23 of Set 8 | sinabang
# Processing Record 24 of Set 8 | manggar
# Processing Record 25 of Set 8 | morondava
# Processing Record 26 of Set 8 | atafu village
# Processing Record 27 of Set 8 | harar
# Processing Record 28 of Set 8 | jha-jha
# Processing Record 29 of Set 8 | xuanzhou
# Processing Record 30 of Set 8 | svay rieng
# Processing Record 31 of Set 8 | chokwe
# Processing Record 32 of Set 8 | salahonda
# Processing Record 33 of Set 8 | cockburn town
# Processing Record 34 of Set 8 | el matama
# Processing Record 35 of Set 8 | severo-yeniseyskiy
# Processing Record 36 of Set 8 | guiuan
# Processing Record 37 of Set 8 | lata
# Processing Record 38 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 39 of Set 8 | sola
# Processing Record 40 of Set 8 | moengo
# Processing Record 41 of Set 8 | waddan
# Processing Record 42 of Set 8 | mount pearl
# Processing Record 43 of Set 8 | sur
# Processing Record 44 of Set 8 | howrah
# Processing Record 45 of Set 8 | sarupathar
# Processing Record 46 of Set 8 | katsuura
# Processing Record 47 of Set 8 | shaowu
# Processing Record 48 of Set 8 | fort bragg
# Processing Record 49 of Set 8 | aykhal
# Processing Record 0 of Set 9 | porto novo
# Processing Record 1 of Set 9 | mont-dore
# Processing Record 2 of Set 9 | daru
# Processing Record 3 of Set 9 | belyy yar
# Processing Record 4 of Set 9 | rio grande
# Processing Record 5 of Set 9 | illizi
# Processing Record 6 of Set 9 | las palmas
# Processing Record 7 of Set 9 | egilsstadir
# Processing Record 8 of Set 9 | elesbao veloso
# Processing Record 9 of Set 9 | yilan
# Processing Record 10 of Set 9 | anna regina
# Processing Record 11 of Set 9 | port saint john's
# Processing Record 12 of Set 9 | suai
# City not found. Skipping...
# Processing Record 13 of Set 9 | salekhard
# Processing Record 14 of Set 9 | aqadyr
# Processing Record 15 of Set 9 | al kharijah
# Processing Record 16 of Set 9 | gisborne
# Processing Record 17 of Set 9 | la passe
# Processing Record 18 of Set 9 | maragogi
# Processing Record 19 of Set 9 | bowen
# Processing Record 20 of Set 9 | cole harbour
# Processing Record 21 of Set 9 | bacliff
# Processing Record 22 of Set 9 | wewak
# Processing Record 23 of Set 9 | corner brook
# Processing Record 24 of Set 9 | zhaotong
# Processing Record 25 of Set 9 | huetamo de nunez
# Processing Record 26 of Set 9 | brokopondo
# Processing Record 27 of Set 9 | narvik
# Processing Record 28 of Set 9 | antonio enes
# Processing Record 29 of Set 9 | lensk
# Processing Record 30 of Set 9 | manay
# Processing Record 31 of Set 9 | sandnessjoen
# Processing Record 32 of Set 9 | nantucket
# Processing Record 33 of Set 9 | bernardino de campos
# Processing Record 34 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 35 of Set 9 | astara
# Processing Record 36 of Set 9 | xai-xai
# Processing Record 37 of Set 9 | sarandi grande
# Processing Record 38 of Set 9 | chernyshevskiy
# Processing Record 39 of Set 9 | watsa
# Processing Record 40 of Set 9 | kalundborg
# Processing Record 41 of Set 9 | centralia
# Processing Record 42 of Set 9 | mansalay
# Processing Record 43 of Set 9 | preston
# Processing Record 44 of Set 9 | pohang
# Processing Record 45 of Set 9 | kruisfontein
# Processing Record 46 of Set 9 | al marj
# Processing Record 47 of Set 9 | timimoun
# Processing Record 48 of Set 9 | laminusa
# Processing Record 49 of Set 9 | altay
# Processing Record 0 of Set 10 | znamenskoye
# Processing Record 1 of Set 10 | maintirano
# Processing Record 2 of Set 10 | bongor
# Processing Record 3 of Set 10 | djambala
# Processing Record 4 of Set 10 | mawu
# Processing Record 5 of Set 10 | lhasa
# Processing Record 6 of Set 10 | patong
# Processing Record 7 of Set 10 | viedma
# Processing Record 8 of Set 10 | alva
# Processing Record 9 of Set 10 | sungai penuh
# Processing Record 10 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 11 of Set 10 | punta cana
# Processing Record 12 of Set 10 | lukolela
# Processing Record 13 of Set 10 | sao domingos do maranhao
# Processing Record 14 of Set 10 | new norfolk
# Processing Record 15 of Set 10 | kogalym
# Processing Record 16 of Set 10 | verkhnevilyuysk
# Processing Record 17 of Set 10 | gering
# Processing Record 18 of Set 10 | san mariano
# Processing Record 19 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 20 of Set 10 | boa vista
# Processing Record 21 of Set 10 | gracemere
# Processing Record 22 of Set 10 | viitasaari
# Processing Record 23 of Set 10 | aoulef
# Processing Record 24 of Set 10 | mugia
# Processing Record 25 of Set 10 | taounate
# Processing Record 26 of Set 10 | shache
# Processing Record 27 of Set 10 | turaif
# Processing Record 28 of Set 10 | alesund
# Processing Record 29 of Set 10 | isla mujeres
# Processing Record 30 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 31 of Set 10 | murghob
# Processing Record 32 of Set 10 | decorah
# Processing Record 33 of Set 10 | mercedes
# Processing Record 34 of Set 10 | ipatovo
# Processing Record 35 of Set 10 | bei'an
# Processing Record 36 of Set 10 | carnarvon
# Processing Record 37 of Set 10 | lompoc
# Processing Record 38 of Set 10 | wynyard
# Processing Record 39 of Set 10 | angaur state
# Processing Record 40 of Set 10 | nogliki
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | pytalovo
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | smach mean chey
# City not found. Skipping...
# Processing Record 45 of Set 10 | nahiyat al fuhud
# Processing Record 46 of Set 10 | yishui
# Processing Record 47 of Set 10 | dauphin
# Processing Record 48 of Set 10 | nelson bay
# Processing Record 49 of Set 10 | lubao
# Processing Record 0 of Set 11 | khash
# Processing Record 1 of Set 11 | zaragoza
# Processing Record 2 of Set 11 | keren
# Processing Record 3 of Set 11 | ancud
# Processing Record 4 of Set 11 | susuman
# Processing Record 5 of Set 11 | bardai
# Processing Record 6 of Set 11 | malvan
# Processing Record 7 of Set 11 | zouerate
# Processing Record 8 of Set 11 | papao
# Processing Record 9 of Set 11 | pelham
# Processing Record 10 of Set 11 | namdrik
# Processing Record 11 of Set 11 | biltine
# Processing Record 12 of Set 11 | coyhaique
# Processing Record 13 of Set 11 | yuzhno-kurilsk
# Processing Record 14 of Set 11 | naze
# Processing Record 15 of Set 11 | kasongo-lunda
# Processing Record 16 of Set 11 | qamdo
# Processing Record 17 of Set 11 | gulf shores
# Processing Record 18 of Set 11 | kailua-kona
# Processing Record 19 of Set 11 | wanning
# Processing Record 20 of Set 11 | goundam
# Processing Record 21 of Set 11 | ushtobe
# Processing Record 22 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 23 of Set 11 | sandy
# Processing Record 24 of Set 11 | injambakkam
# City not found. Skipping...
# Processing Record 25 of Set 11 | constitucion
# Processing Record 26 of Set 11 | port augusta
# Processing Record 27 of Set 11 | cleveland
# Processing Record 28 of Set 11 | ahvaz
# Processing Record 29 of Set 11 | big lake
# Processing Record 30 of Set 11 | nizhneudinsk
# Processing Record 31 of Set 11 | port macquarie
# Processing Record 32 of Set 11 | inekar
# City not found. Skipping...
# Processing Record 33 of Set 11 | nurlat
# Processing Record 34 of Set 11 | jining
# Processing Record 35 of Set 11 | alvaraes
# Processing Record 36 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 11 | tanah merah
# Processing Record 38 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 39 of Set 11 | rybnoye
# Processing Record 40 of Set 11 | al bardiyah
# Processing Record 41 of Set 11 | pyapon
# Processing Record 42 of Set 11 | forbes
# Processing Record 43 of Set 11 | locust grove
# Processing Record 44 of Set 11 | bolobo
# Processing Record 45 of Set 11 | hacienda huancane
# Processing Record 46 of Set 11 | es castell
# Processing Record 47 of Set 11 | wamba
# Processing Record 48 of Set 11 | villa union
# Processing Record 49 of Set 11 | flying fish cove
# Processing Record 0 of Set 12 | bakanas
# Processing Record 1 of Set 12 | alaghsas
# Processing Record 2 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 4 of Set 12 | santa cruz cabralia
# Processing Record 5 of Set 12 | tukrah
# Processing Record 6 of Set 12 | bar
# Processing Record 7 of Set 12 | dukuhturi
# Processing Record 8 of Set 12 | pyt-yakh
# Processing Record 9 of Set 12 | ruelle-sur-touvre
# Processing Record 10 of Set 12 | waupun
# Processing Record 11 of Set 12 | umluj
# Processing Record 12 of Set 12 | sanming
# Processing Record 13 of Set 12 | mogadishu
# Processing Record 14 of Set 12 | chinde
# Processing Record 15 of Set 12 | bua yai
# Processing Record 16 of Set 12 | nadvoitsy
# Processing Record 17 of Set 12 | 'ain el turk
# Processing Record 18 of Set 12 | hola
# Processing Record 19 of Set 12 | tafuna
# Processing Record 20 of Set 12 | kongsvinger
# Processing Record 21 of Set 12 | lachi
# Processing Record 22 of Set 12 | am timan
# Processing Record 23 of Set 12 | beaufort west
# Processing Record 24 of Set 12 | ballina
# Processing Record 25 of Set 12 | happy valley-goose bay
# Processing Record 26 of Set 12 | nampa
# Processing Record 27 of Set 12 | petrolina
# Processing Record 28 of Set 12 | ballito
# Processing Record 29 of Set 12 | carbonear
# Processing Record 30 of Set 12 | tayoltita
# Processing Record 31 of Set 12 | kencong
# Processing Record 32 of Set 12 | puerto santa
# Processing Record 33 of Set 12 | katoomba
# Processing Record 34 of Set 12 | kindu
# Processing Record 35 of Set 12 | minot
# Processing Record 36 of Set 12 | rikaze
# Processing Record 37 of Set 12 | el abiodh sidi cheikh
# Processing Record 38 of Set 12 | holualoa
# Processing Record 39 of Set 12 | al mithnab
# City not found. Skipping...
# Processing Record 40 of Set 12 | yamada
# Processing Record 41 of Set 12 | vanino
# Processing Record 42 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 43 of Set 12 | hovd
# Processing Record 44 of Set 12 | pereslavl'-zalesskiy
# Processing Record 45 of Set 12 | el kef
# Processing Record 46 of Set 12 | pante makasar
# City not found. Skipping...
# Processing Record 47 of Set 12 | tha mai
# Processing Record 48 of Set 12 | saldanha
# Processing Record 49 of Set 12 | aldan
# Processing Record 0 of Set 13 | tyrnyauz
# Processing Record 1 of Set 13 | queen creek
# Processing Record 2 of Set 13 | al bayda'
# Processing Record 3 of Set 13 | burao
# Processing Record 4 of Set 13 | el calafate
# Processing Record 5 of Set 13 | banda aceh
# Processing Record 6 of Set 13 | coahuayana de hidalgo
# Processing Record 7 of Set 13 | fisterra
# Processing Record 8 of Set 13 | paradip garh
# Processing Record 9 of Set 13 | san luis de la loma
# Processing Record 10 of Set 13 | acajutla
# Processing Record 11 of Set 13 | queenstown
# Processing Record 12 of Set 13 | saudarkrokur
# Processing Record 13 of Set 13 | shitanjing
# Processing Record 14 of Set 13 | dedougou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df['Date'] = city_data_df['Date'].str.split(' ').str[0]
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     cabedelo  -6.9811  -34.8339    302.30        77          70        4.01
# 1       acarau  -2.8856  -40.1200    300.79        80          93        3.13
# 2  blairgowrie  56.5916   -3.3405    281.23        69           5        2.16
# 3       sinmak  38.4167  126.2333    287.86        78          63        1.02
# 4    adamstown -25.0660 -130.1015    297.86        76          59        2.30
#
#   Country        Date
# 0      BR  2023-04-19
# 1      BR  2023-04-19
# 2      GB  2023-04-19
# 3      KP  2023-04-19
# 4      PN  2023-04-19

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           cabedelo  -6.9811  -34.8339    302.30        77          70
# 1             acarau  -2.8856  -40.1200    300.79        80          93
# 2        blairgowrie  56.5916   -3.3405    281.23        69           5
# 3             sinmak  38.4167  126.2333    287.86        78          63
# 4          adamstown -25.0660 -130.1015    297.86        76          59
#
#          Wind Speed Country        Date
# City_ID
# 0              4.01      BR  2023-04-19
# 1              3.13      BR  2023-04-19
# 2              2.16      GB  2023-04-19
# 3              1.02      KP  2023-04-19
# 4              2.30      PN  2023-04-19

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Temperature ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Humidity ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Cloudiness ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Latitude vs. Wind Speed ({city_data_df["Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
