# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
print("Number of documents:", establishments.count_documents(query))

# Display the first document in the results using pprint
print("First document:")
pprint(establishments.find_one(query))
# Out:
# Number of documents: 41
# First document:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed505382'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
print("Number of rows:", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  646695eda8f19ea1ed505382   110681                  0
# 1  646695eda8f19ea1ed5056f9   612039                  0
# 2  646695eda8f19ea1ed505a0c   730933                  0
# 3  646695eda8f19ea1ed505bfa   172735                  0
# 4  646695eda8f19ea1ed505c08   172953                  0
# 5  646695eda8f19ea1ed5065ab   512854                  0
# 6  646695eda8f19ea1ed5067c1  1537089                  0
# 7  646695eea8f19ea1ed507cf3   155648                  0
# 8  646695eea8f19ea1ed508137  1012883                  0
# 9  646695eea8f19ea1ed508955   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {"$regex": "London", "$options": "i"}, "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
print("Number of establishments in London with a RatingValue >= 4:",establishments.count_documents(query))

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of establishments in London with a RatingValue >= 4: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506da9'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
print("Number of rows:", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  646695eda8f19ea1ed506da9   621707                  0
# 1  646695eea8f19ea1ed5070bc  1130836                  0
# 2  646695eea8f19ea1ed507c0d   293783                  0
# 3  646695eea8f19ea1ed508a0f   294474                  0
# 4  646695eea8f19ea1ed508a1e  1315095                  0
# 5  646695eea8f19ea1ed509118   294900                  0
# 6  646695eea8f19ea1ed50b225   293756                  0
# 7  646695eea8f19ea1ed50b5ed   878523                  0
# 8  646695eea8f19ea1ed50b606   294606                  0
# 9  646695eea8f19ea1ed50b607   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000036464  Coombs Catering t/a The Lock and Key
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000016185                              WH Smith
# 9             PI/000002585         The Nuance Group (UK) Limited
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                          Tenants Row Tilbury Docks
# 4                                  Leslie Ford House
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                                London City Airport
# 9                  Duty Free Shop Passenger Terminal
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                         Tilbury Essex               ...
# 4                               Tilbury     Charlton  ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8                     Silvertown London               ...
# 9  London City AirportRoyal DocksLondon               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3     {'longitude': 0.346325, 'latitude': 51.464078}
# 4  {'longitude': 0.346336990594864, 'latitude': 5...
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8  {'longitude': 0.0479655750095844, 'latitude': ...
# 9     {'longitude': 0.047966, 'latitude': 51.504112}
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.847650            False
# 4  4636.846754            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188850            False
# 9  4649.188826            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01

penang_flavours = establishments.find_one(query)
latitude = penang_flavours['geocode']['latitude']
longitude = penang_flavours['geocode']['longitude']

query = {
    "RatingValue": 5,
    "geocode.latitude": {
        "$gt": latitude - degree_search,
        "$lt": latitude + degree_search},
    "geocode.longitude": {
        "$gt": longitude - degree_search,
        "$lt": longitude + degree_search
    }
}

sort = [("scores.Hygiene", 1)]

results = establishments.find(query).sort(sort)

# Print the results
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '110 Pattens Lane',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'News Shop',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.071735597095,
#  'FHRSID': 786158,
#  'LocalAuthorityBusinessID': 'PI/000030142',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2RA',
#  'RatingDate': '2017-09-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506bac'),
#  'geocode': {'latitude': 51.366737, 'longitude': 0.516021},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/786158',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '1A Beatty Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'One Stop',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.164964441188,
#  'FHRSID': 783911,
#  'LocalAuthorityBusinessID': 'PI/000002329',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2TG',
#  'RatingDate': '2015-07-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506c10'),
#  'geocode': {'latitude': 51.36393, 'longitude': 0.510609},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/783911',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '1 Beatty Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Papas Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.165001454627,
#  'FHRSID': 605582,
#  'LocalAuthorityBusinessID': 'PI/000002322',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2TG',
#  'RatingDate': '2020-11-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506c11'),
#  'geocode': {'latitude': 51.363931, 'longitude': 0.510609},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/605582',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Pattens Lane',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Medway',
#  'AddressLine4': '',
#  'BusinessName': 'Our Zone',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4627.191477028352,
#  'FHRSID': 1079636,
#  'LocalAuthorityBusinessID': '18/00543/CP',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2RB',
#  'RatingDate': '2021-09-29T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506c2a'),
#  'geocode': {'latitude': 51.368408203125, 'longitude': 0.514432013034821},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1079636',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '99B Warren Wood Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Medway',
#  'AddressLine4': '',
#  'BusinessName': 'Warren Wood Social Club',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.227944225703,
#  'FHRSID': 683394,
#  'LocalAuthorityBusinessID': 'PI/000187947',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2XA',
#  'RatingDate': '2018-09-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506c5c'),
#  'geocode': {'latitude': 51.3600486, 'longitude': 0.5049371},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/683394',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Flat',
#  'AddressLine2': 'General At Sea',
#  'AddressLine3': '1A Balfour Road',
#  'AddressLine4': 'Chatham',
#  'BusinessName': 'The General At Sea PH',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4627.2587030631685,
#  'FHRSID': 778612,
#  'LocalAuthorityBusinessID': 'PI/000097691',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME4 6QT',
#  'RatingDate': '2015-06-29T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506c80'),
#  'geocode': {'latitude': 51.3721723, 'longitude': 0.5164123},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/778612',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Balfour Infant School',
#  'AddressLine2': 'Pattens Lane',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Chartwells',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4627.29615537853,
#  'FHRSID': 609865,
#  'LocalAuthorityBusinessID': 'PI/000030154',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2QT',
#  'RatingDate': '2019-10-31T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506ca8'),
#  'geocode': {'latitude': 51.3700523376465, 'longitude': 0.513229012489319},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/609865',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'St Lukes Church',
#  'AddressLine2': 'City Way',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Lukes Pre School',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4627.328752974475,
#  'FHRSID': 705248,
#  'LocalAuthorityBusinessID': 'PI/000008171',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2BQ',
#  'RatingDate': '2022-03-01T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506cc9'),
#  'geocode': {'latitude': 51.3666496276855, 'longitude': 0.508876025676727},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/705248',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'The George',
#  'AddressLine2': '344 City Way',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': '',
#  'BusinessName': "Mumma Soraya's",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.38192284944,
#  'FHRSID': 1181403,
#  'LocalAuthorityBusinessID': '19/00240/CP',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2BH',
#  'RatingDate': '2022-03-01T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506d3d'),
#  'geocode': {'latitude': 51.368526, 'longitude': 0.509323},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1181403',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'The George',
#  'AddressLine2': '344 City Way',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The George',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4627.382327799895,
#  'FHRSID': 740186,
#  'LocalAuthorityBusinessID': 'PI/000096033',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2BH',
#  'RatingDate': '2022-04-26T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506d3f'),
#  'geocode': {'latitude': 51.3685024, 'longitude': 0.5092879},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/740186',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Co Op Petrol Station',
#  'AddressLine2': 'City Way Service Station',
#  'AddressLine3': '342 City Way',
#  'AddressLine4': 'Rochester',
#  'BusinessName': 'Co-Operative',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.399134035892,
#  'FHRSID': 705247,
#  'LocalAuthorityBusinessID': 'PI/000008111',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2BJ',
#  'RatingDate': '2021-09-26T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506d5e'),
#  'geocode': {'latitude': 51.3698844909668, 'longitude': 0.510231018066406},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/705247',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'The Fairway',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'St Justus Church Hall',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4627.606305773035,
#  'FHRSID': 737950,
#  'LocalAuthorityBusinessID': 'PI/000243535',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2LT',
#  'RatingDate': '2022-06-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506eaf'),
#  'geocode': {'latitude': 51.367027, 'longitude': 0.50164},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/737950',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Valley View Nursing Home',
#  'AddressLine2': 'Maidstone Road',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Valley View Residential Nursing Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4627.6122728422015,
#  'FHRSID': 745546,
#  'LocalAuthorityBusinessID': 'PI/000130779',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3LT',
#  'RatingDate': '2019-04-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506ec3'),
#  'geocode': {'latitude': 51.3642387390137, 'longitude': 0.49864399433136},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/745546',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Rochester Grammar School For Girls',
#  'AddressLine2': 'Maidstone Road',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Chartwells',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.797901463014,
#  'FHRSID': 934127,
#  'LocalAuthorityBusinessID': 'PI/000250529',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3BY',
#  'RatingDate': '2020-10-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed507048'),
#  'geocode': {'latitude': 51.371452331543, 'longitude': 0.500876009464264},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/934127',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Carpenters Arms',
#  'AddressLine2': '13 Cossack Street',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Carpenters Arms',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4627.833449863218,
#  'FHRSID': 754561,
#  'LocalAuthorityBusinessID': 'PI/000151078',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2EF',
#  'RatingDate': '2015-04-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed507086'),
#  'geocode': {'latitude': 51.3789816, 'longitude': 0.5075516},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/754561',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Sir Joseph Williamsons Mathematical School',
#  'AddressLine2': 'Maidstone Road',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Medway',
#  'BusinessName': 'Impact Food Group',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4627.833752423255,
#  'FHRSID': 1269423,
#  'LocalAuthorityBusinessID': '20/00316/CP',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3EL',
#  'RatingDate': '2021-07-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed507089'),
#  'geocode': {'latitude': 51.3702638, 'longitude': 0.4986843},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1269423',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '4 Cossack Street',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Rochester Best Kebab',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.833922564734,
#  'FHRSID': 528509,
#  'LocalAuthorityBusinessID': 'PI/000009545',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2EF',
#  'RatingDate': '2021-11-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed50708b'),
#  'geocode': {'latitude': 51.379041, 'longitude': 0.507599},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/528509',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'St Peters Infant School',
#  'AddressLine2': 'Holcombe Road',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Chartwells',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4627.860254600747,
#  'FHRSID': 806033,
#  'LocalAuthorityBusinessID': 'PI/000250093',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2HU',
#  'RatingDate': '2022-03-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed5070c1'),
#  'geocode': {'latitude': 51.3771629333496, 'longitude': 0.504966974258423},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/806033',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '126A Maidstone Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Bean Town Coffee',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4628.028800272932,
#  'FHRSID': 620931,
#  'LocalAuthorityBusinessID': 'PI/000248201',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3DT',
#  'RatingDate': '2022-01-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed507189'),
#  'geocode': {'latitude': 51.377164, 'longitude': 0.50034},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/620931',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '27-31 Pattens Lane',
#  'AddressLine2': 'Chatham',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Co-Op',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4626.994613645115,
#  'FHRSID': 783921,
#  'LocalAuthorityBusinessID': 'PI/000030119',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME4 6JR',
#  'RatingDate': '2015-08-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506b4d'),
#  'geocode': {'latitude': 51.366103, 'longitude': 0.517494},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/783921',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'The Huntsman',
#  'AddressLine2': '106 Pattens Lane',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Medway',
#  'BusinessName': 'Que & Brew Smokehouse',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.068948009548,
#  'FHRSID': 1423359,
#  'LocalAuthorityBusinessID': '21/00411/CP',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2RA',
#  'RatingDate': '2022-02-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506ba8'),
#  'geocode': {'latitude': 51.3666861, 'longitude': 0.5160458},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1423359',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '108 Pattens Lane',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Sealand Fish And Chips',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.071735597095,
#  'FHRSID': 802088,
#  'LocalAuthorityBusinessID': 'PI/000251174',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2RA',
#  'RatingDate': '2022-03-01T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506ba9'),
#  'geocode': {'latitude': 51.366737, 'longitude': 0.516021},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/802088',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': 'The Huntsman PH',
#  'AddressLine2': 'The Huntsman',
#  'AddressLine3': '106 Pattens Lane',
#  'AddressLine4': 'Rochester',
#  'BusinessName': 'The Huntsman',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4627.068948009548,
#  'FHRSID': 510152,
#  'LocalAuthorityBusinessID': 'PI/000243002',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2RA',
#  'RatingDate': '2022-02-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506baa'),
#  'geocode': {'latitude': 51.3666861, 'longitude': 0.5160458},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/510152',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'The Scout Hut',
#  'AddressLine2': 'Beresford Avenue',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Beresford Pre-School',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4627.2555587195,
#  'FHRSID': 802068,
#  'LocalAuthorityBusinessID': 'PI/000002758',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2QX',
#  'RatingDate': '2015-09-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506c7d'),
#  'geocode': {'latitude': 51.3710581, 'longitude': 0.515366},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/802068',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Rochester Care Home',
#  'AddressLine2': 'Pattens Lane',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Robert Bean Lodge',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4627.29615537853,
#  'FHRSID': 732110,
#  'LocalAuthorityBusinessID': 'PI/000030153',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2QT',
#  'RatingDate': '2022-05-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506ca9'),
#  'geocode': {'latitude': 51.3700523376465, 'longitude': 0.513229012489319},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/732110',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': '53-55 Orion Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'McColls',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.369651339995,
#  'FHRSID': 783928,
#  'LocalAuthorityBusinessID': 'PI/000205215',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2UH',
#  'RatingDate': '2022-01-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506d19'),
#  'geocode': {'latitude': 51.361002, 'longitude': 0.502016},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/783928',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '69 - 71 City Way',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Karsons Pharmacy',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.432192514221,
#  'FHRSID': 1064353,
#  'LocalAuthorityBusinessID': '18/00492/CP',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2BA',
#  'RatingDate': '2018-07-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506d95'),
#  'geocode': {'latitude': 51.3716752, 'longitude': 0.5111433},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1064353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': '66 The Fairway',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Fairway Food & Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.607598136827,
#  'FHRSID': 692131,
#  'LocalAuthorityBusinessID': 'PI/000155786',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2LU',
#  'RatingDate': '2017-05-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506eb2'),
#  'geocode': {'latitude': 51.367812, 'longitude': 0.502402},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/692131',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Petrol Filling Station',
#  'AddressLine2': 'Maidstone Road',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Shell Rochester Service Station',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.6122728422015,
#  'FHRSID': 624400,
#  'LocalAuthorityBusinessID': 'PI/000246780',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3LT',
#  'RatingDate': '2022-01-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506ee0'),
#  'geocode': {'latitude': 51.3642387390137, 'longitude': 0.49864399433136},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/624400',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '7-11 Central Parade',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Co-Op',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4627.657078176076,
#  'FHRSID': 683397,
#  'LocalAuthorityBusinessID': 'PI/000206642',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2LQ',
#  'RatingDate': '2022-02-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506f28'),
#  'geocode': {'latitude': 51.373245, 'longitude': 0.506564},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/683397',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '212-214 Maidstone Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Medway',
#  'AddressLine4': '',
#  'BusinessName': 'HD Express',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.739943584126,
#  'FHRSID': 1063518,
#  'LocalAuthorityBusinessID': '18/00074/REG',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3LP',
#  'RatingDate': '2022-01-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eda8f19ea1ed506fcb'),
#  'geocode': {'latitude': 51.3683174, 'longitude': 0.4992823},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1063518',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '212-214 Maidstone Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Medway',
#  'AddressLine4': '',
#  'BusinessName': 'HD Express',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.739943584126,
#  'FHRSID': 1063518,
#  'LocalAuthorityBusinessID': '18/00074/REG',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3LP',
#  'RatingDate': '2022-01-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed507009'),
#  'geocode': {'latitude': 51.3683174, 'longitude': 0.4992823},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1063518',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '166 Delce Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Jasmine Garden',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.79788597505,
#  'FHRSID': 528546,
#  'LocalAuthorityBusinessID': 'PI/000244138',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2EP',
#  'RatingDate': '2022-02-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed50704e'),
#  'geocode': {'latitude': 51.37858, 'longitude': 0.50812},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/528546',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '141 Cecil Road',
#  'AddressLine2': 'Rochester',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Chips On The Hill',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4627.803069251184,
#  'FHRSID': 734931,
#  'LocalAuthorityBusinessID': 'PI/000142898',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 2HW',
#  'RatingDate': '2022-02-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed507072'),
#  'geocode': {'latitude': 51.378055, 'longitude': 0.507444},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/734931',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Little Explorers Day Nursery',
#  'AddressLine2': '206C Maidstone Road',
#  'AddressLine3': 'Rochester',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Explorers Day Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4627.888108378574,
#  'FHRSID': 580478,
#  'LocalAuthorityBusinessID': 'PI/000025422',
#  'LocalAuthorityCode': '896',
#  'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#  'LocalAuthorityName': 'Medway',
#  'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME1 3EJ',
#  'RatingDate': '2021-10-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646695eea8f19ea1ed5070d6'),
#  'geocode': {'latitude': 51.371711730957, 'longitude': 0.498663008213043},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/580478',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query).sort(sort).limit(5)))
print("Number of rows:", len(df))
df.head(10)
# Out:
# Number of rows: 5
#                         _id   FHRSID  ChangesByServerID  \
# 0  646695eda8f19ea1ed506c11   605582                  0
# 1  646695eda8f19ea1ed506c10   783911                  0
# 2  646695eda8f19ea1ed506c5c   683394                  0
# 3  646695eda8f19ea1ed506c2a  1079636                  0
# 4  646695eda8f19ea1ed506bac   786158                  0
#
#   LocalAuthorityBusinessID             BusinessName            BusinessType  \
# 0             PI/000002322           Papas Fish Bar  Takeaway/sandwich shop
# 1             PI/000002329                 One Stop       Retailers - other
# 2             PI/000187947  Warren Wood Social Club       Retailers - other
# 3              18/00543/CP                 Our Zone         Caring Premises
# 4             PI/000030142                News Shop       Retailers - other
#
#    BusinessTypeID          AddressLine1 AddressLine2 AddressLine3  ...  \
# 0            7844         1 Beatty Road    Rochester         Kent  ...
# 1            4613        1A Beatty Road    Rochester         Kent  ...
# 2            4613  99B Warren Wood Road    Rochester       Medway  ...
# 3               5          Pattens Lane    Rochester       Medway  ...
# 4            4613      110 Pattens Lane    Rochester         Kent  ...
#
#        LocalAuthorityWebSite   LocalAuthorityEmailAddress  \
# 0  http://www.medway.gov.uk/  foodandsafety@medway.gov.uk
# 1  http://www.medway.gov.uk/  foodandsafety@medway.gov.uk
# 2  http://www.medway.gov.uk/  foodandsafety@medway.gov.uk
# 3  http://www.medway.gov.uk/  foodandsafety@medway.gov.uk
# 4  http://www.medway.gov.uk/  foodandsafety@medway.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.510609, 'latitude': 51.363931}
# 1      {'longitude': 0.510609, 'latitude': 51.36393}
# 2   {'longitude': 0.5049371, 'latitude': 51.3600486}
# 3  {'longitude': 0.514432013034821, 'latitude': 5...
# 4     {'longitude': 0.516021, 'latitude': 51.366737}
#
#       Distance NewRatingPending  \
# 0  4627.165001            False
# 1  4627.164964            False
# 2  4627.227944            False
# 3  4627.191477            False
# 4  4627.071736            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    { "$match": { "scores.Hygiene": 0 } },
    { "$group": {
        "_id": "$LocalAuthorityName",
        "count": { "$sum": 1 }
    }},
    {"$sort": {"count": -1}},
    {"$limit": 10}
]

results = list(db.establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of documents:", len(results))

# Print the first 10 results
for i, r in enumerate(results[:10]):
    print(f"{i+1}. {r['_id']}: {r['count']}")
# Out:
# Number of documents: 10
# 1. Thanet: 1130
# 2. Greenwich: 882
# 3. Maidstone: 713
# 4. Newham: 711
# 5. Swale: 686
# 6. Chelmsford: 680
# 7. Medway: 672
# 8. Bexley: 607
# 9. Southend-On-Sea: 586
# 10. Tendring: 542

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number of rows:", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows: 10
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
