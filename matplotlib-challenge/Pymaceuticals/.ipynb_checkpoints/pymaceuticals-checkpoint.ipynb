# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = 'data/Mouse_metadata.csv'
study_results_path = 'data/Study_results.csv'

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_data_complete = pd.merge(study_results, mouse_metadata, how='left', on=['Mouse ID', 'Mouse ID'])

# Display the data table for preview
mouse_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_num_count = mouse_data_complete.nunique()['Mouse ID']
mouse_num_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_duplicates = mouse_data_complete[mouse_data_complete.duplicated(['Mouse ID', 'Timepoint'])]['Mouse ID'].unique()
mouse_duplicates
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
mouse_duplicates_data = mouse_data_complete.loc[mouse_data_complete['Mouse ID'] == mouse_duplicates[0]]
mouse_duplicates_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_data = mouse_data_complete[~mouse_data_complete['Mouse ID'].isin(mouse_duplicates)]
clean_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_num_count = clean_mouse_data.nunique()['Mouse ID']
clean_mouse_num_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, std dev, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

summ_stats = clean_mouse_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
summ_stats.columns = [
    'Mean Tumor Volume',
    'Median Tumor Volume',
    'Tumor Volume Variance',
    'Tumor Volume Std. Dev.',
    'Tumor Volume Std. Err.'
]
summ_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
summ_stats_one_line = clean_mouse_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem']).rename_axis(columns=['Tumor Volume (mm3)'])
summ_stats_one_line
# Out:
# Tumor Volume (mm3)       mean     median        var       std       sem
# Drug Regimen
# Capomulin           40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin            52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol           52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril            55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol            54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo             54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva            52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane            40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn            54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol           53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

plt_timepoints = clean_mouse_data.groupby('Drug Regimen')['Timepoint'].count().sort_values(ascending=False)
plt_timepoints.plot(kind='bar', rot=45, title='Total Timepoints for all Mice Tested per Drug Regimen using Pandas')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

plt.bar(plt_timepoints.index, plt_timepoints.values)
plt.xticks(rotation=45)
plt.title('Total Timepoints for all Mice Tested per Drug Regimen using Pyplot')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

plt_sex = clean_mouse_data['Sex'].value_counts()
plt_sex.plot(kind='pie', autopct='%1.1f%%', title='Distribution of Female vs Male Mice using Pandas')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

plt_sex = clean_mouse_data['Sex'].value_counts()
plt.pie(plt_sex, labels=plt_sex.index, autopct='%1.1f%%')
plt.title('Distribution of Female vs Male Mice using Pyplot')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
grouped_df = clean_mouse_data.groupby('Mouse ID').agg({'Timepoint': 'max'})
#grouped_df

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merged_df = pd.merge(grouped_df, clean_mouse_data, on=['Mouse ID', 'Timepoint'], how='left')
#merged_df

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
#treatments

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_data = []
#tumor_vol_data

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for treatment in treatments:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    subset = merged_df.loc[merged_df['Drug Regimen'] == treatment]['Tumor Volume (mm3)']
    tumor_volume_data.append(subset)
    
    # add subset 
    quartiles = subset.quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr_value = st.iqr(subset)
    lower_bound = lowerq - (1.5 * iqr_value)
    upper_bound = upperq + (1.5 * iqr_value)
    
    # Determine outliers using upper and lower bounds
    outliers = subset.loc[(subset < lower_bound) | (subset > upper_bound)]
    print(f"{treatment}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

fig, plt_box_plot = plt.subplots()
plt_box_plot.boxplot(tumor_volume_data, labels=treatments, flierprops=dict(markerfacecolor='red', marker='o', markersize=10))
plt_box_plot.set_ylabel('Final Tumor Volume (mm3)')
plt_box_plot.set_title('Distribution of Tumor Volume per Treatment Group')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

capomulin_data = clean_mouse_data[clean_mouse_data['Drug Regimen'] == 'Capomulin']

mouse_id = 'l509'
mouse_data = capomulin_data[capomulin_data['Mouse ID'] == mouse_id]

fig, single_mouse = plt.subplots()
single_mouse.plot(mouse_data['Timepoint'], mouse_data['Tumor Volume (mm3)'])
single_mouse.set_xlabel('Timepoint (days)')
single_mouse.set_ylabel('Tumor Volume (mm3)')
single_mouse.set_title(f'Capomulin treatment of mouse {mouse_id}')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

avg_capomulin_data = capomulin_data.groupby('Mouse ID').mean()
fig, avg_mouse = plt.subplots()
avg_mouse.scatter(avg_capomulin_data['Weight (g)'], avg_capomulin_data['Tumor Volume (mm3)'])
avg_mouse.set_xlabel('Weight (g)')
avg_mouse.set_ylabel('Average Tumor Volume (mm3)')
avg_mouse.set_title('Average Tumor Volume vs Mouse Weight for the Capomulin Treatment Regimen')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model
# for mouse weight and average tumor volume for the Capomulin regimen

corr_coef, _ = st.pearsonr(avg_capomulin_data['Weight (g)'], avg_capomulin_data['Average Tumor Volume (mm3)'])
print(f"The correlation between mouse weight and the average tumor volume is {corr_coef:.2f}")

slope, intercept, rvalue, _, _ = st.linregress(avg_capomulin_data['Weight (g)'], avg_capomulin_data['Average Tumor Volume (mm3)'])
regression_values = slope * avg_capomulin_data['Weight (g)'] + intercept

fig, corr_regr_plot = plt.subplots()
corr_regr_plot.scatter(avg_capomulin_data['Weight (g)'], avg_capomulin_data['Average Tumor Volume (mm3)'])
corr_regr_plot.plot(avg_capomulin_data['Weight (g)'], regression_values, color='red')
corr_regr_plot.set_xlabel('Weight (g)')
corr_regr_plot.set_ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
